# %% [markdown]
# ### Ingesta de Paracas
#
# Este cuaderno separa **foto patrimonial** y **imagen técnica**. Esa separación es central para no pedirle el mismo tipo de texto a modalidades distintas.

# %%
from pathlib import Path
import sys
import json
import pandas as pd

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.io_utils import jsonl_load, jsonl_dump

raw_objects = jsonl_load(PROJECT_ROOT / "data_raw/paracas/metadata/paracas_objects_raw.jsonl")
raw_analysis = jsonl_load(PROJECT_ROOT / "data_raw/paracas/metadata/paracas_analysis_raw.jsonl")
len(raw_objects), len(raw_analysis)
# Out:
# (2, 1)

# %% [markdown]
# #### Fotos vs. XRF
#
# Una ficha patrimonial rica en descripción e iconografía puede alimentar captioning factual y nota curatorial. Un mapa XRF, en cambio, exige una salida técnico-analítica y más cautela inferencial.

# %%
master = jsonl_load(PROJECT_ROOT / "data_processed/records_master.jsonl")
paracas = [r for r in master if r["source"] == "paracas"]
pd.DataFrame(paracas)[["record_id", "modality_type", "title", "date_display", "split"]]
# Out:
#                    record_id modality_type  \
# 0  par_1932_01_0005_photo_01         photo
# 1  par_1935_32_0212_photo_01         photo
# 2    par_xrf_em1932_01_0013e       xrf_map
#
#                                                title  \
# 0              Fragmento textil Paracas 1932.01.0005
# 1           Fragmentos de manto Paracas 1935.32.0212
# 2  Mapa XRF de muestra textil Paracas EM1932.01.0...
#
#                                         date_display      split
# 0     sin fecha única; ficha de colección consultada      train
# 1   Intermedio Temprano 1B–2 (ca. 100 a.C.–200 d.C.)       test
# 2  dataset publicado en 2021; objeto histórico Pa...  challenge
