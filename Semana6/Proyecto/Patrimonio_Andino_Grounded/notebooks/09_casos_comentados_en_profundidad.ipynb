# %% [markdown]
# ### Casos comentados en profundidad
#
# Este cuaderno reúne dos lecturas cercanas sobre la muestra real pequeña. La idea es mostrar cómo cambian la interpretación y el tipo de salida cuando el registro depende más de la **estructura** o más de la **materialidad visual y curatorial**.

# %% [markdown]
# #### 1. Cargar la muestra y las salidas disponibles

# %%
# Carga registros y localizar los casos comentados desde la muestra real.
from pathlib import Path
import json
import pandas as pd

NOTEBOOK_DIR = Path.cwd().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent if NOTEBOOK_DIR.name == "notebooks" else NOTEBOOK_DIR
RECORDS_PATH = PROJECT_ROOT / "data_processed" / "records_master.jsonl"

records = [json.loads(line) for line in RECORDS_PATH.read_text(encoding="utf-8").splitlines() if line.strip()]
df = pd.DataFrame(records)
print("Registros disponibles:", len(df))
df[["record_id", "title", "source", "modality_type"]]
# Out:
# Registros disponibles: 7
#                    record_id  \
# 0        okr_kh_0068_view_01
# 1        okr_kh_0082_view_01
# 2        okr_kh_0323_view_01
# 3        okr_kh_0328_view_01
# 4  par_1932_01_0005_photo_01
# 5  par_1935_32_0212_photo_01
# 6    par_xrf_em1932_01_0013e
#
#                                                title      source modality_type
# 0                       Khipu KH0068 (UR1057, AS057)  open_khipu      no_image
# 1                               Khipu KH0082 (AS069)  open_khipu      no_image
# 2                               Khipu KH0323 (UR087)  open_khipu      no_image
# 3                               Khipu KH0328 (UR092)  open_khipu      no_image
# 4              Fragmento textil Paracas 1932.01.0005     paracas         photo
# 5           Fragmentos de manto Paracas 1935.32.0212     paracas         photo
# 6  Mapa XRF de muestra textil Paracas EM1932.01.0...     paracas       xrf_map

# %% [markdown]
# #### 2. Caso A - Open Khipu KH0082
#
# En este caso, el problema no es "qué objeto aparece en la foto", sino **cómo describir una entidad cuya evidencia principal es estructural**. Eso obliga a privilegiar jerarquía, conteos, proveniencia y notas del catálogo.

# %%
case_a = {
    "record_id": "okr_kh_0082_view_01",
    "canonical_id": "kh_0082",
    "source": "open_khipu",
    "source_record_id": "KH0082",
    "modality_type": "no_image",
    "title": "Khipu KH0082 (AS069)",
    "description": "Khipu grande de colección privada Percy Dauelsberg, Arica, asociado a Lluta Valley; 458 grupos y 1831 cordeles.",
    "object_type": "Khipu",
    "culture": "Andean",
    "date_display": "sin fecha específica en la ficha consultada",
    "date_begin": None,
    "date_end": None,
    "medium": "fibra textil anudada",
    "provenance": "Lluta Valley",
    "institution": "Open Khipu Repository / Khipu Field Guide",
    "collection": "OKR",
    "rights": "open metadata",
    "language": "es",
    "tags": [
        "khipu",
        "AS069",
        "Lluta Valley",
        "Arica",
        "large khipu",
    ],
    "image_path": None,
    "image_url": None,
    "thumbnail_path": None,
    "split": "train",
    "x_s": {
        "material": "fibra textil",
        "cord_count": 1831,
        "pendant_count": 1650,
        "top_cord": None,
        "knot_types": [],
        "spin_ply": None,
        "color_terms": [],
        "hierarchy": "458 grupos",
        "attachment_structure": None,
        "unique_colors": 46,
    },
    "x_t": {
        "title": "Khipu KH0082 (AS069)",
        "description": "Private collection Percy Dauelsberg, Arica; provenance Lluta Valley; 1831 cords.",
        "keywords": [
            "Percy Dauelsberg",
            "Lluta Valley",
            "46 colors",
        ],
    },
    "x_c": {
        "chronology": None,
        "geography": "Arica, Chile",
        "museum": "Private collection, Percy Dauelsberg (current location unknown)",
        "museum_number": "4",
        "region": "Unknown",
        "reference_url": "https://www.khipufieldguide.com/catalog/KH0082.html",
        "dataset_note": "Curated from Khipu Field Guide public catalog",
    },
    "qa_flags": {
        "missing_image": True,
        "missing_date": True,
        "missing_material": False,
        "curated_from_public_web_metadata": True,
    },
}

case_a
# Out:
# {'record_id': 'okr_kh_0082_view_01',
#  'canonical_id': 'kh_0082',
#  'source': 'open_khipu',
#  'source_record_id': 'KH0082',
#  'modality_type': 'no_image',
#  'title': 'Khipu KH0082 (AS069)',
#  'description': 'Khipu grande de colección privada Percy Dauelsberg, Arica, asociado a Lluta Valley; 458 grupos y 1831 cordeles.',
#  'object_type': 'Khipu',
#  'culture': 'Andean',
#  'date_display': 'sin fecha específica en la ficha consultada',
#  'date_begin': None,
#  'date_end': None,
#  'medium': 'fibra textil anudada',
#  'provenance': 'Lluta Valley',
#  'institution': 'Open Khipu Repository / Khipu Field Guide',
#  'collection': 'OKR',
#  'rights': 'open metadata',
#  'language': 'es',
#  'tags': ['khipu', 'AS069', 'Lluta Valley', 'Arica', 'large khipu'],
#  'image_path': None,
#  'image_url': None,
#  'thumbnail_path': None,
#  'split': 'train',
#  'x_s': {'material': 'fibra textil',
#   'cord_count': 1831,
#   'pendant_count': 1650,
#   'top_cord': None,
#   'knot_types': [],
# ...

# %% [markdown]
# #### Comentario del caso A
#
# - `modality_type = no_image` obliga a renunciar a una lectura puramente visual.
# - La descripción útil depende de `cord_count`, `pendant_count`, `hierarchy` y procedencia.
# - La salida grounded debe evitar llenar vacíos con inferencias iconográficas o cromáticas no sustentadas.
# - Este caso es ideal para discutir por qué **Open Khipu no debe tratarse como un corpus visual genérico**.

# %% [markdown]
# #### 3. Caso B - Paracas 1935.32.0212
#
# Aquí sí hay una lógica más cercana a imagen patrimonial + metadatos curatoriales. Aun así, la salida no debería reducirse a "fragmento textil colorido", porque el valor está en técnica, iconografía, condición y contexto de colección.

# %%
case_b = {
    "record_id": "par_1935_32_0212_photo_01",
    "canonical_id": "par_1935_32_0212",
    "source": "paracas",
    "source_record_id": "1935.32.0212",
    "modality_type": "photo",
    "title": "Fragmentos de manto Paracas 1935.32.0212",
    "description": "Dieciséis fragmentos bordados de un manto Paracas, en block style, con figura antropomorfa, múltiples serpientes y dieciséis colores.",
    "object_type": "Textile",
    "culture": "Paracas",
    "date_display": "Intermedio Temprano 1B–2 (ca. 100 a.C.–200 d.C.)",
    "date_begin": -100,
    "date_end": 200,
    "medium": "algodón en la base; bordado de lana",
    "provenance": "Paracas, Peru",
    "institution": "National Museums of World Culture (Sweden)",
    "collection": "Carlotta / Museum of World Culture",
    "rights": "metadata public",
    "language": "es",
    "tags": [
        "Paracas",
        "mantle field embroidery fragments",
        "block style",
        "16 colors",
    ],
    "image_path": None,
    "image_url": None,
    "thumbnail_path": None,
    "split": "test",
    "x_s": {
        "material": "base de algodón; bordado de lana",
        "pattern_type": "block style / figura antropomorfa",
        "color_terms": ["amarillo", "rojo", "azul", "marrón", "negro"],
        "technique": "bordado en punto de tallo sobre tejido llano",
        "iconography_terms": [
            "figura antropomorfa",
            "serpientes",
            "cabezas trofeo",
        ],
        "condition_note": "16 fragmentos; partes del manto posiblemente recortadas",
        "analysis_type": None,
        "element": None,
        "sample_id": None,
    },
    "x_t": {
        "title": "Fragmentos de manto Paracas 1935.32.0212",
        "description": "16 brown fragments from a Paracas mantle; anthropomorphic figure, snakes and dense embroidery in 16 colors.",
        "keywords": [
            "1935.32.0212",
            "Paracas Necropolis",
            "16 colors",
            "block style",
            "embroidery",
        ],
    },
    "x_c": {
        "chronology": "Paracas Necropolis, Early Intermediate Period 1B–2",
        "geography": "Paracas, Peru",
        "museum": "National Museums of World Culture",
        "collection_url": "https://collections.smvk.se/carlotta-vkm/web/object/96713",
        "dataset_note": "Curated from SMVK object page",
    },
    "qa_flags": {
        "missing_image": True,
        "missing_date": False,
        "missing_material": False,
        "curated_from_public_web_metadata": True,
    },
}

case_b
# Out:
# {'record_id': 'par_1935_32_0212_photo_01',
#  'canonical_id': 'par_1935_32_0212',
#  'source': 'paracas',
#  'source_record_id': '1935.32.0212',
#  'modality_type': 'photo',
#  'title': 'Fragmentos de manto Paracas 1935.32.0212',
#  'description': 'Dieciséis fragmentos bordados de un manto Paracas, en block style, con figura antropomorfa, múltiples serpientes y dieciséis colores.',
#  'object_type': 'Textile',
#  'culture': 'Paracas',
#  'date_display': 'Intermedio Temprano 1B–2 (ca. 100 a.C.–200 d.C.)',
#  'date_begin': -100,
#  'date_end': 200,
#  'medium': 'algodón en la base; bordado de lana',
#  'provenance': 'Paracas, Peru',
#  'institution': 'National Museums of World Culture (Sweden)',
#  'collection': 'Carlotta / Museum of World Culture',
#  'rights': 'metadata public',
#  'language': 'es',
#  'tags': ['Paracas',
#   'mantle field embroidery fragments',
#   'block style',
#   '16 colors'],
#  'image_path': None,
#  'image_url': None,
#  'thumbnail_path': None,
# ...

# %% [markdown]
# #### Comentario del caso B
#
# - La salida descriptiva puede ser más visual que en Open Khipu.
# - La ficha técnica aporta materialidad, técnica de bordado, cromática e iconografía.
# - La comparación con vecinos recuperados es útil para contexto, pero no prueba identidad de origen o función.
# - Este caso muestra bien la diferencia entre un caption factual y una nota técnico-curatorial.

# %% [markdown]
# ## 4. Cierre comparativo
#
# **Caso A (KH0082)** pide una descripción disciplinada por estructura y procedencia.
# **Caso B (Paracas 1935.32.0212)** permite una salida más visual, pero sigue necesitando evidencia técnica y curatorial.
#
# La comparación entre ambos casos resume el argumento central del proyecto: **no toda modalidad patrimonial pide el mismo tipo de texto**.
