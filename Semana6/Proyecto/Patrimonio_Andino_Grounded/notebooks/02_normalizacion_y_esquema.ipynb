# %% [markdown]
# ### Normalización y esquema
#
# Aquí se revisa el esquema común que permite trabajar Open Khipu y Paracas bajo una sola lógica experimental.

# %%
from pathlib import Path
import sys
import json
import pandas as pd

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.io_utils import jsonl_load, jsonl_dump

from src.schema_validators import validate_records

records = jsonl_load(PROJECT_ROOT / "data_processed/records_master.jsonl")
validation = validate_records(records)
pd.DataFrame(validation)
# Out:
#                    record_id errors  is_valid
# 0        okr_kh_0068_view_01     []      True
# 1        okr_kh_0082_view_01     []      True
# 2        okr_kh_0323_view_01     []      True
# 3        okr_kh_0328_view_01     []      True
# 4  par_1932_01_0005_photo_01     []      True
# 5  par_1935_32_0212_photo_01     []      True
# 6    par_xrf_em1932_01_0013e     []      True

# %% [markdown]
# #### Vista de los bloques
#
# - `x_s`: estructura y materialidad.
# - `x_t`: texto catalográfico útil para recuperación.
# - `x_c`: contexto curatorial.
# - `qa_flags`: faltantes y advertencias.

# %%
records[0]
# Out:
# {'record_id': 'okr_kh_0068_view_01',
#  'canonical_id': 'kh_0068',
#  'source': 'open_khipu',
#  'source_record_id': 'KH0068',
#  'modality_type': 'no_image',
#  'title': 'Khipu KH0068 (UR1057, AS057)',
#  'description': 'Khipu registrado en el Museo Regional de Ica Adolfo Bermúdez Jenkins, con 94 grupos y 589 cordeles.',
#  'object_type': 'Khipu',
#  'culture': 'Andean',
#  'date_display': 'sin fecha específica en la ficha consultada',
#  'date_begin': None,
#  'date_end': None,
#  'medium': 'fibra textil anudada',
#  'provenance': 'Unknown',
#  'institution': 'Open Khipu Repository / Khipu Field Guide',
#  'collection': 'OKR',
#  'rights': 'open metadata',
#  'language': 'es',
#  'tags': ['khipu', 'UR1057', 'AS057', 'Ica', 'cord hierarchy'],
#  'image_path': None,
#  'image_url': None,
#  'thumbnail_path': None,
#  'split': 'train',
#  'x_s': {'material': 'fibra textil',
#   'cord_count': 589,
#   'pendant_count': 558,
#   'top_cord': None,
#   'knot_types': [],
# ...
