# %% [markdown]
# ### Recuperación base e índices
#
# La recuperación se usa como parte de la evidencia. No es un adorno para el cuaderno: define el contexto comparativo y disciplina la generación.

# %%
from pathlib import Path
import sys
import json
import pandas as pd

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.io_utils import jsonl_load, jsonl_dump

from src.retrieval import fit_text_retriever, retrieve_neighbors_tfidf

records = jsonl_load(PROJECT_ROOT / "data_processed/records_master.jsonl")
retriever = fit_text_retriever(records)
query = "Paracas textile with block style embroidery and anthropomorphic figure"
neighbors = retrieve_neighbors_tfidf(query, retriever, top_k=3)
pd.DataFrame(neighbors)
# Out:
#                    record_id             canonical_id  \
# 0  par_1935_32_0212_photo_01         par_1935_32_0212
# 1  par_1932_01_0005_photo_01         par_1932_01_0005
# 2    par_xrf_em1932_01_0013e  par_xrf_em1932_01_0013e
#
#                                                title   source     score  \
# 0           Fragmentos de manto Paracas 1935.32.0212  paracas  0.399488
# 1              Fragmento textil Paracas 1932.01.0005  paracas  0.323252
# 2  Mapa XRF de muestra textil Paracas EM1932.01.0...  paracas  0.126568
#
#                                          description
# 0  Dieciséis fragmentos bordados de un manto Para...
# 1  Fragmento arqueológico textil Paracas de estil...
# 2  Registro analítico del conjunto XRF maps of Pa...

# %% [markdown]
# #### Lectura conceptual
#
# La recuperación textual base usa TF-IDF para dejar clara la lógica experimental. Más adelante puede reemplazarse por embeddings reales, pero conviene conservar una línea base interpretable.

# %%
query = "Khipu from Santa with many cords and museum metadata"
pd.DataFrame(retrieve_neighbors_tfidf(query, retriever, top_k=3))
# Out:
#              record_id canonical_id                 title      source  \
# 0  okr_kh_0328_view_01      kh_0328  Khipu KH0328 (UR092)  open_khipu
# 1  okr_kh_0323_view_01      kh_0323  Khipu KH0323 (UR087)  open_khipu
# 2  okr_kh_0082_view_01      kh_0082  Khipu KH0082 (AS069)  open_khipu
#
#       score                                        description
# 0  0.239252  Khipu del conjunto de Santa, conservado en el ...
# 1  0.223584  Khipu del conjunto de Santa, conservado en el ...
# 2  0.078516  Khipu grande de colección privada Percy Dauels...
