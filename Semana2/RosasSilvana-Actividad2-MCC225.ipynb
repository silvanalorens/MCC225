# %% [markdown]
# **Construcción del vocabulario **
#
# El primer paso es construir el vocabulario más cercano a multimedia y deportes, es decir, asignar a cada palabra única un identificador numérico. Se recorre cada documento y se separa en palabras:

# %% [markdown]
# Para la comparación se utilizó los captions obtenido de ActivityNet explicado en OpenClip-MCC225.ipynb

# %%
docs = [
    "woman dancing",
    "man playing tennis",
    "person playing music",
    "dog running",
    "goal celebration",
    "penalty kick"
]

# %% [markdown]
# pudiendo ser la salida {
#  'woman': 0,
#  'dancing': 1,
#  'man': 2,
#  'playing': 3,
#  'tennis': 4,
#  'person': 5,
#  'music': 6,
#  'dog': 7,
#  'running': 8,
#  'goal': 9,
#  'celebration': 10,
#  'penalty': 11,
#  'kick': 12
# }
